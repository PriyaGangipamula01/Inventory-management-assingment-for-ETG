# %%
# READ THE DATA FROM JSON

import json

fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
# PRINT THE RECORD

record
# Out:
# {'1001': {'name': 'Choco Cake', 'qn': 34, 'pr': 100},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 100},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 100},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1000},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 100},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 0},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10}}

# %%
# ADDING NEW ITEMS TO THE INVENTORY

def add_inventory():
    prod_id = str(input("Enter product id:"))
    name = str(input("Enter name:"))
    pr = int(input("Enter price:"))
    qn = int(input("Enter quantity:"))
    
    record[prod_id] = {'name': name, 'pr': pr, 'qn': qn}
    
val=True
while val:
    print("1.add a item to the inventory")
    print("2.quit")
    choice=int(input("Enter your choice: "))
    if(choice==1):
        add_inventory()
    elif(choice==2):
        val=False
    else:
        print("enter correct choice")
    
js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1010
# Enter name:Pencil
# Enter price:10
# Enter quantity:234
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1011
# Enter name:Notebook
# Enter price:15
# Enter quantity:123
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1012
# Enter name:Earphones
# Enter price:399
# Enter quantity:19
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1013
# Enter name:Speakers
# Enter price:699
# Enter quantity:45
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1014
# Enter name:Bag
# Enter price:400
# Enter quantity:23
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1015
# Enter name:Choco cookies
# Enter price:30
# Enter quantity:124
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1016
# Enter name:Milk biscuits
# Enter price:15
# Enter quantity:47
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1017
# Enter name:Backpack
# Enter price:600
# Enter quantity:24
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1018
# Enter name:Watch
# Enter price:899
# Enter quantity:10
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1019
# Enter name:Headphones
# Enter price:799
# Enter quantity:7
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1020
# Enter name:Potato chips
# Enter price:15
# Enter quantity:67
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1021
# Enter name:Adapter
# Enter price:499
# Enter quantity:12
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1022
# Enter name:Choclates
# Enter price:10
# Enter quantity:56
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1023
# Enter name:Pendrive
# Enter price:199
# Enter quantity:23
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1024
# Enter name:Camera
# Enter price:699
# Enter quantity:5
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1025
# Enter name:Mango juice
# Enter price:35
# Enter quantity:3
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1026
# Enter name:Laptop bag
# Enter price:1999
# Enter quantity:2
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1027
# Enter name:Mice
# Enter price:600
# Enter quantity:4
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1028
# Enter name:Calculator
# Enter price:699
# Enter quantity:1
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1029
# enter correct choice
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1029
# Enter name:Noodles
# Enter price:20
# Enter quantity:57
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:103
# Enter name:Pencil
# Enter price:5
# Enter quantity:278
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 1
# Enter product id:1030
# Enter name:Oats
# Enter price:15
# Enter quantity:356
# 1.add a item to the inventory
# 2.quit
# Enter your choice: 2

# %%
del record['103']
record
# Out:
# {'1001': {'name': 'Choco Cake', 'qn': 34, 'pr': 100},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 100},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 100},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1000},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 100},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 0},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10},
#  '1010': {'name': 'Pencil', 'pr': 10, 'qn': 234},
#  '1011': {'name': 'Notebook', 'pr': 15, 'qn': 123},
#  '1012': {'name': 'Earphones', 'pr': 399, 'qn': 19},
#  '1013': {'name': 'Speakers', 'pr': 699, 'qn': 45},
#  '1014': {'name': 'Bag', 'pr': 400, 'qn': 23},
#  '1015': {'name': 'Choco cookies', 'pr': 30, 'qn': 124},
#  '1016': {'name': 'Milk biscuits', 'pr': 15, 'qn': 47},
#  '1017': {'name': 'Backpack', 'pr': 600, 'qn': 24},
#  '1018': {'name': 'Watch', 'pr': 899, 'qn': 10},
#  '1019': {'name': 'Headphones', 'pr': 799, 'qn': 7},
#  '1020': {'name': 'Potato chips', 'pr': 15, 'qn': 67},
#  '1021': {'name': 'Adapter', 'pr': 499, 'qn': 12},
#  '1022': {'name': 'Choclates', 'pr': 10, 'qn': 56},
#  '1023': {'name': 'Pendrive', 'pr': 199, 'qn': 23},
#  '1024': {'name': 'Camera', 'pr': 699, 'qn': 5},
#  '1025': {'name': 'Mango juice', 'pr': 35, 'qn': 3},
#  '1026': {'name': 'Laptop bag', 'pr': 1999, 'qn': 2},
#  '1027': {'name': 'Mice', 'pr': 600, 'qn': 4},
#  '1028': {'name': 'Calculator', 'pr': 699, 'qn': 1},
#  '1029': {'name': 'Noodles', 'pr': 20, 'qn': 57},
#  '1030': {'name': 'Oats', 'pr': 15, 'qn': 356}}

# %%
record['1007']['qn']=7
record
# Out:
# {'1001': {'name': 'Choco Cake', 'qn': 34, 'pr': 100},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 100},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 100},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1000},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 100},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 7},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10},
#  '1010': {'name': 'Pencil', 'pr': 10, 'qn': 234},
#  '1011': {'name': 'Notebook', 'pr': 15, 'qn': 123},
#  '1012': {'name': 'Earphones', 'pr': 399, 'qn': 19},
#  '1013': {'name': 'Speakers', 'pr': 699, 'qn': 45},
#  '1014': {'name': 'Bag', 'pr': 400, 'qn': 23},
#  '1015': {'name': 'Choco cookies', 'pr': 30, 'qn': 124},
#  '1016': {'name': 'Milk biscuits', 'pr': 15, 'qn': 47},
#  '1017': {'name': 'Backpack', 'pr': 600, 'qn': 24},
#  '1018': {'name': 'Watch', 'pr': 899, 'qn': 10},
#  '1019': {'name': 'Headphones', 'pr': 799, 'qn': 7},
#  '1020': {'name': 'Potato chips', 'pr': 15, 'qn': 67},
#  '1021': {'name': 'Adapter', 'pr': 499, 'qn': 12},
#  '1022': {'name': 'Choclates', 'pr': 10, 'qn': 56},
#  '1023': {'name': 'Pendrive', 'pr': 199, 'qn': 23},
#  '1024': {'name': 'Camera', 'pr': 699, 'qn': 5},
#  '1025': {'name': 'Mango juice', 'pr': 35, 'qn': 3},
#  '1026': {'name': 'Laptop bag', 'pr': 1999, 'qn': 2},
#  '1027': {'name': 'Mice', 'pr': 600, 'qn': 4},
#  '1028': {'name': 'Calculator', 'pr': 699, 'qn': 1},
#  '1029': {'name': 'Noodles', 'pr': 20, 'qn': 57},
#  '1030': {'name': 'Oats', 'pr': 15, 'qn': 356}}

# %%
#UPDATING JSON FILE AFTER MODIFICATIONS

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
record
# Out:
# {'1001': {'name': 'Choco Cake', 'qn': 34, 'pr': 100},
#  '1002': {'name': 'Milk Cake', 'pr': 800, 'qn': 100},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 100},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1000},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 100},
#  '1006': {'name': 'Phone', 'pr': 50000, 'qn': 10},
#  '1007': {'name': 'Mic', 'pr': 1500, 'qn': 7},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10},
#  '1010': {'name': 'Pencil', 'pr': 10, 'qn': 234},
#  '1011': {'name': 'Notebook', 'pr': 15, 'qn': 123},
#  '1012': {'name': 'Earphones', 'pr': 399, 'qn': 19},
#  '1013': {'name': 'Speakers', 'pr': 699, 'qn': 45},
#  '1014': {'name': 'Bag', 'pr': 400, 'qn': 23},
#  '1015': {'name': 'Choco cookies', 'pr': 30, 'qn': 124},
#  '1016': {'name': 'Milk biscuits', 'pr': 15, 'qn': 47},
#  '1017': {'name': 'Backpack', 'pr': 600, 'qn': 24},
#  '1018': {'name': 'Watch', 'pr': 899, 'qn': 10},
#  '1019': {'name': 'Headphones', 'pr': 799, 'qn': 7},
#  '1020': {'name': 'Potato chips', 'pr': 15, 'qn': 67},
#  '1021': {'name': 'Adapter', 'pr': 499, 'qn': 12},
#  '1022': {'name': 'Choclates', 'pr': 10, 'qn': 56},
#  '1023': {'name': 'Pendrive', 'pr': 199, 'qn': 23},
#  '1024': {'name': 'Camera', 'pr': 699, 'qn': 5},
#  '1025': {'name': 'Mango juice', 'pr': 35, 'qn': 3},
#  '1026': {'name': 'Laptop bag', 'pr': 1999, 'qn': 2},
#  '1027': {'name': 'Mice', 'pr': 600, 'qn': 4},
#  '1028': {'name': 'Calculator', 'pr': 699, 'qn': 1},
#  '1029': {'name': 'Noodles', 'pr': 20, 'qn': 57},
#  '1030': {'name': 'Oats', 'pr': 15, 'qn': 356}}
